# %% [markdown]
# <a href="https://colab.research.google.com/github/deepakjayakumar/Scaler_Python/blob/main/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if(5>6):
  print(True)
else:
  print(False)
# Out:
# False
